# %% [markdown]
# ### Storytelling Project
# ##### Find the driver of customers churning on month-to-month plan.

# %%
import pandas as pd
import numpy as np
from pydataset import data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv('customer_spreadsheet.csv')
customers.sample(5)
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 5857  8231-BSWXX    Male                  0      No         No              2
# 3969  5583-SXDAG    Male                  0     Yes         No              1
# 6488  9191-MYQKX  Female                  0     Yes         No              1
# 2877  4092-OFQZS    Male                  0     Yes         No              1
# 3548  5027-QPKTE    Male                  0     Yes         No              1
#
#       internet_service  contract_type               payment_type  \
# 5857                 2              1    Credit card (automatic)
# 3969                 2              0           Electronic check
# 6488                 2              0  Bank transfer (automatic)
# 2877                 0              1               Mailed check
# 3548                 2              0           Electronic check
#
#      monthly_charges  ... no_dependents_yes_partners dependents_no_partners  \
# ...

# %%
customers.groupby('contract_type').agg(sum)
# Out:
#                is_senior_citizen  phone_service  internet_service  tenure  \
# contract_type
# 0                            807           4981              5479   69832
# 1                            190           1944              1648   61919
# 2                            145           2407              1486   96219
#
#                is_female  has_churned  has_phone  has_internet  \
# contract_type
# 0                   1925         1655       3499          3351
# 1                    718          166       1328          1109
# 2                    845           48       1534          1057
#
#                has_phone_and_internet  partner_dependents  Unnamed: 23  \
# contract_type
# 0                                2975                2958          0.0
# 1                                 964                1892          0.0
# 2                                 896                2772          3.0
#
#                 start_date  validate_monthly_charges
# contract_type
# ...

# %%
customers.columns
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents',
#        'phone_service', 'internet_service', 'contract_type', 'payment_type',
#        'monthly_charges', 'total_charges', 'churn', 'tenure', 'is_female',
#        'has_churned', 'has_phone', 'has_internet', 'has_phone_and_internet',
#        'partner_dependents', 'no_partners_no_dependents',
#        'no_dependents_yes_partners', 'dependents_no_partners',
#        'yes_dependents_and_partners', 'Unnamed: 23', 'start_date',
#        'average_monthly_charges', 'validate_monthly_charges',
#        'contract_type_desc', 'phone_type_desc', 'internet_type_desc'],
#       dtype='object')

# %%
customers[['churn', 'contract_type']].sample(10)
# Out:
#      churn  contract_type
# 5817    No              0
# 5024   Yes              0
# 1341   Yes              0
# 3924   Yes              0
# 4785    No              0
# 1809    No              2
# 4167   Yes              0
# 605    Yes              0
# 6933   Yes              0
# 5560    No              2

# %%
customers.contract_type.value_counts()
# Out:
# 0    3875
# 2    1695
# 1    1473
# Name: contract_type, dtype: int64

# %%
customers.contract_type.value_counts()
# Out:
# 0    3875
# 2    1695
# 1    1473
# Name: contract_type, dtype: int64

# %%
customers.churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: churn, dtype: int64
